# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('loan-train.csv')

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Loan_ID'].nunique()
# Out:
# 614

# %%
df['Married'].value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
df['ApplicantIncome'].unique()
# Out:
# array([ 5849,  4583,  3000,  2583,  6000,  5417,  2333,  3036,  4006,
#        12841,  3200,  2500,  3073,  1853,  1299,  4950,  3596,  3510,
#         4887,  2600,  7660,  5955,  3365,  3717,  9560,  2799,  4226,
#         1442,  3750,  4166,  3167,  4692,  3500, 12500,  2275,  1828,
#         3667,  3748,  3600,  1800,  2400,  3941,  4695,  3410,  5649,
#         5821,  2645,  4000,  1928,  3086,  4230,  4616, 11500,  2708,
#         2132,  3366,  8080,  3357,  3029,  2609,  4945,  5726, 10750,
#         7100,  4300,  3208,  1875,  4755,  5266,  1000,  3333,  3846,
#         2395,  1378,  3988,  2366,  8566,  5695,  2958,  6250,  3273,
#         4133,  3620,  6782,  2484,  1977,  4188,  1759,  4288,  4843,
#        13650,  4652,  3816,  3052, 11417,  7333,  3800,  2071,  5316,
#         2929,  3572,  7451,  5050, 14583,  2214,  5568, 10408,  5667,
#         2137,  2957,  3692, 23803,  3865, 10513,  6080, 20166,  2014,
#         2718,  3459,  4895,  3316, 14999,  4200,  5042,  6950,  2698,
#        11757,  2330, 14866,  1538, 10000,  4860,  6277,  2577,  9166,
#         2281,  3254, 39999,  9538,  2980,  1863,  7933,  3089,  4167,
#         9323,  3707,  2439,  2237,  8000,  1820, 51763,  3522,  5708,
#         4344,  3497,  2045,  5516,  6400,  1916,  4600, 33846,  3625,
#        39147,  2178,  2383,   674,  9328,  4885, 12000,  6033,  3858,
#         4191,  3125,  8333,  1907,  3416, 11000,  4923,  3992,  3917,
#         4408,  3244,  3975,  2479,  3418,  3430,  7787,  5703,  3173,
#         3850,   150,  3727,  5000,  4283,  2221,  4009,  2971,  7578,
#         3250,  4735,  4758,  2491,  3716,  3189,  3155,  5500,  5746,
#         3463,  3812,  3315,  5819,  2510,  2965,  3406,  6050,  9703,
#         6608,  2882,  1809,  1668,  3427,  2661, 16250,  3083,  6045,
#         5250, 14683,  4931,  6083,  2060,  3481,  7200,  5166,  4095,
#         4708,  4333,  2876,  3237, 11146,  2833,  2620,  3900,  2750,
#         3993,  3103,  4100,  4053,  3927,  2301,  1811, 20667,  3158,
#         3704,  4124,  9508,  3075,  4400,  3153,  4416,  6875,  4666,
#         2875,  1625,  2000,  3762, 20233,  7667,  2917,  2927,  2507,
#         2473,  3399,  2058,  3541,  4342,  3601,  3166, 15000,  8666,
#         4917,  5818,  4384,  2935, 63337,  9833,  5503,  1830,  4160,
#         2647,  2378,  4554,  2499,  3523,  6333,  2625,  9083,  8750,
#         2666,  2423,  3813,  3875,  5167,  4723,  4750,  3013,  6822,
#         6216,  5124,  6325, 19730, 15759,  5185,  3062,  2764,  4817,
#         4310,  3069,  5391,  5941,  7167,  4566,  2346,  3010,  5488,
#         9167,  9504,  1993,  3100,  3276,  3180,  3033,  3902,  1500,
#         2889,  2755,  1963,  7441,  4547,  2167,  2213,  8300, 81000,
#         3867,  6256,  6096,  2253,  2149,  2995,  1600,  1025,  3246,
#         5829,  2720,  7250, 14880,  4606,  5935,  2920,  2717,  8624,
#         6500, 12876,  2425, 10047,  1926, 10416,  7142,  3660,  7901,
#         4707, 37719,  3466,  3539,  3340,  2769,  2309,  1958,  3948,
#         2483,  7085,  3859,  4301,  3708,  4354,  8334,  2083,  7740,
#         3015,  5191,  2947, 16692,   210,  3450,  2653,  4691,  5532,
#        16525,  6700,  2873, 16667,  4350,  3095, 10833,  3547, 18333,
#         2435,  2699,  5333,  3691, 17263,  3597,  3326,  4625,  2895,
#         6283,   645,  3159,  4865,  4050,  3814, 20833,  3583, 13262,
#         3598,  6065,  3283,  2130,  5815,  2031,  3074,  4683,  3400,
#         2192,  5677,  7948,  4680, 17500,  3775,  5285,  2679,  6783,
#         4281,  3588, 11250, 18165,  2550,  6133,  3617,  6417,  4608,
#         2138,  3652,  2239,  3017,  2768,  3358,  2526,  2785,  6633,
#         2492,  2454,  3593,  5468,  2667, 10139,  3887,  4180,  3675,
#        19484,  5923,  5800,  8799,  4467,  3417,  5116, 16666,  6125,
#         6406,  3087,  3229,  1782,  3182,  6540,  1836,  1880,  2787,
#         2297,  2165,  2726,  9357, 16120,  3833,  6383,  2987,  9963,
#         5780,   416,  2894,  3676,  3987,  3232,  2900,  4106,  8072,
#         7583], dtype=int64)

# %%
df['CoapplicantIncome'].unique()
# Out:
# array([0.00000000e+00, 1.50800000e+03, 2.35800000e+03, 4.19600000e+03,
#        1.51600000e+03, 2.50400000e+03, 1.52600000e+03, 1.09680000e+04,
#        7.00000000e+02, 1.84000000e+03, 8.10600000e+03, 2.84000000e+03,
#        1.08600000e+03, 3.50000000e+03, 5.62500000e+03, 1.91100000e+03,
#        1.91700000e+03, 2.92500000e+03, 2.25300000e+03, 1.04000000e+03,
#        2.08300000e+03, 3.36900000e+03, 1.66700000e+03, 3.00000000e+03,
#        2.06700000e+03, 1.33000000e+03, 1.45900000e+03, 7.21000000e+03,
#        1.66800000e+03, 1.21300000e+03, 2.33600000e+03, 3.44000000e+03,
#        2.27500000e+03, 1.64400000e+03, 1.16700000e+03, 1.59100000e+03,
#        2.20000000e+03, 2.25000000e+03, 2.85900000e+03, 3.79600000e+03,
#        3.44900000e+03, 4.59500000e+03, 2.25400000e+03, 3.06600000e+03,
#        1.87500000e+03, 1.77400000e+03, 4.75000000e+03, 3.02200000e+03,
#        4.00000000e+03, 2.16600000e+03, 1.88100000e+03, 2.53100000e+03,
#        2.00000000e+03, 2.11800000e+03, 4.16700000e+03, 2.90000000e+03,
#        5.65400000e+03, 1.82000000e+03, 2.30200000e+03, 9.97000000e+02,
#        3.54100000e+03, 3.26300000e+03, 3.80600000e+03, 3.58300000e+03,
#        7.54000000e+02, 1.03000000e+03, 1.12600000e+03, 3.60000000e+03,
#        2.33300000e+03, 4.11400000e+03, 2.28300000e+03, 1.39800000e+03,
#        2.14200000e+03, 2.66700000e+03, 8.98000000e+03, 2.01400000e+03,
#        1.64000000e+03, 3.85000000e+03, 2.56900000e+03, 1.92900000e+03,
#        7.75000000e+03, 1.43000000e+03, 2.03400000e+03, 4.48600000e+03,
#        1.42500000e+03, 1.66600000e+03, 8.30000000e+02, 3.75000000e+03,
#        1.04100000e+03, 1.28000000e+03, 1.44700000e+03, 3.16600000e+03,
#        3.33300000e+03, 1.76900000e+03, 7.36000000e+02, 1.96400000e+03,
#        1.61900000e+03, 1.13000000e+04, 1.45100000e+03, 7.25000000e+03,
#        5.06300000e+03, 2.13800000e+03, 5.29600000e+03, 2.58300000e+03,
#        2.36500000e+03, 2.81600000e+03, 2.50000000e+03, 1.08300000e+03,
#        1.25000000e+03, 3.02100000e+03, 9.83000000e+02, 1.80000000e+03,
#        1.77500000e+03, 2.38300000e+03, 1.71700000e+03, 2.79100000e+03,
#        1.01000000e+03, 1.69500000e+03, 2.05400000e+03, 2.59800000e+03,
#        1.77900000e+03, 1.26000000e+03, 5.00000000e+03, 1.98300000e+03,
#        5.70100000e+03, 1.30000000e+03, 4.41700000e+03, 4.33300000e+03,
#        1.84300000e+03, 1.86800000e+03, 3.89000000e+03, 2.16700000e+03,
#        7.10100000e+03, 2.10000000e+03, 4.25000000e+03, 2.20900000e+03,
#        3.44700000e+03, 1.38700000e+03, 1.81100000e+03, 1.56000000e+03,
#        1.85700000e+03, 2.22300000e+03, 1.84200000e+03, 3.27400000e+03,
#        2.42600000e+03, 8.00000000e+02, 9.85799988e+02, 3.05300000e+03,
#        2.41600000e+03, 3.33400000e+03, 2.54100000e+03, 2.93400000e+03,
#        1.75000000e+03, 1.80300000e+03, 1.86300000e+03, 2.40500000e+03,
#        2.13400000e+03, 1.89000000e+02, 1.59000000e+03, 2.98500000e+03,
#        4.98300000e+03, 2.16000000e+03, 2.45100000e+03, 1.79300000e+03,
#        1.83300000e+03, 4.49000000e+03, 6.88000000e+02, 4.60000000e+03,
#        1.58700000e+03, 1.22900000e+03, 2.33000000e+03, 2.45800000e+03,
#        3.23000000e+03, 2.16800000e+03, 4.58300000e+03, 6.25000000e+03,
#        5.05000000e+02, 3.16700000e+03, 3.66700000e+03, 3.03300000e+03,
#        5.26600000e+03, 7.87300000e+03, 1.98700000e+03, 9.23000000e+02,
#        4.99600000e+03, 4.23200000e+03, 1.60000000e+03, 3.13600000e+03,
#        2.41700000e+03, 2.11500000e+03, 1.62500000e+03, 1.40000000e+03,
#        4.84000000e+02, 2.00000000e+04, 2.40000000e+03, 2.03300000e+03,
#        3.23700000e+03, 2.77300000e+03, 1.41700000e+03, 1.71900000e+03,
#        4.30000000e+03, 1.61200008e+01, 2.34000000e+03, 1.85100000e+03,
#        1.12500000e+03, 5.06400000e+03, 1.99300000e+03, 8.33300000e+03,
#        1.21000000e+03, 1.37600000e+03, 1.71000000e+03, 1.54200000e+03,
#        1.25500000e+03, 1.45600000e+03, 1.73300000e+03, 2.46600000e+03,
#        4.08300000e+03, 2.18800000e+03, 1.66400000e+03, 2.91700000e+03,
#        2.07900000e+03, 1.50000000e+03, 4.64800000e+03, 1.01400000e+03,
#        1.87200000e+03, 1.60300000e+03, 3.15000000e+03, 2.43600000e+03,
#        2.78500000e+03, 1.13100000e+03, 2.15700000e+03, 9.13000000e+02,
#        1.70000000e+03, 2.85700000e+03, 4.41600000e+03, 3.68300000e+03,
#        5.62400000e+03, 5.30200000e+03, 1.48300000e+03, 6.66700000e+03,
#        3.01300000e+03, 1.28700000e+03, 2.00400000e+03, 2.03500000e+03,
#        6.66600000e+03, 3.66600000e+03, 3.42800000e+03, 1.63200000e+03,
#        1.91500000e+03, 1.74200000e+03, 1.42400000e+03, 7.16600000e+03,
#        2.08700000e+03, 1.30200000e+03, 5.50000000e+03, 2.04200000e+03,
#        3.90600000e+03, 5.36000000e+02, 2.84500000e+03, 2.52400000e+03,
#        6.63000000e+02, 1.95000000e+03, 1.78300000e+03, 2.01600000e+03,
#        2.37500000e+03, 3.25000000e+03, 4.26600000e+03, 1.03200000e+03,
#        2.66900000e+03, 2.30600000e+03, 2.42000000e+02, 2.06400000e+03,
#        4.61000000e+02, 2.21000000e+03, 2.73900000e+03, 2.23200000e+03,
#        3.38370000e+04, 1.52200000e+03, 3.41600000e+03, 3.30000000e+03,
#        1.00000000e+03, 4.16670000e+04, 2.79200000e+03, 4.30100000e+03,
#        3.80000000e+03, 1.41100000e+03, 2.40000000e+02])

# %%
df['LoanAmount'].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
#        376., 117.,  71., 490., 173.,  46., 228., 308., 236., 570., 380.,
#        296., 156., 103.,  45.,  65.,  53., 360.,  62., 218., 178., 239.,
#        405., 148., 190., 149., 153., 162., 230.,  86., 234., 246., 500.,
#        186., 119., 107., 209., 208., 243.,  40., 250., 311., 400., 161.,
#        196., 324., 157., 145., 181.,  26., 211.,   9., 205.,  36.,  61.,
#        146., 292., 142., 350., 496., 253.])

# %%
df['LoanAmount'].isnull().sum()
# Out:
# 22

# %%
df['Credit_History'] = df['Credit_History'] = df['Credit_History'].replace({1:"good",0:'bad'})

# %%
df['Credit_History'].value_counts()
# Out:
# Credit_History
# good    475
# bad      89
# Name: count, dtype: int64

# %%
df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
continous = ['ApplicantIncome' , 'CoapplicantIncome', 'LoanAmount']

discrete_categorical = ['Gender' , 'Married' ,'Education' , 'Self_Employed' , 'Credit_History' , 'Property_Area' , 'Loan_Status']

discrete_count = ['Dependents' , 'Loan_Amount_Term']

# %% [markdown]
# # EDA (Exploratory Data Analysis)
#
# ###  For Continous Variables

# %%
df[continous].describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  592.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   85.587325
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.000000
# 50%        3812.500000        1188.500000  128.000000
# 75%        5795.000000        2297.250000  168.000000
# max       81000.000000       41667.000000  700.000000

# %%
plt.subplot(1,2,1)
sns.boxplot(df['Income'])

plt.subplot(1,2,2)
sns.boxplot(df['LoanAmount'])

plt.suptitle('Outliers Present')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (18,8)

plt.subplot(1,3,1)
sns.histplot(df['ApplicantIncome'] , kde = True)

plt.subplot(1,3,2)
sns.histplot(df['CoapplicantIncome'] , kde = True)

plt.subplot(1,3,3)
sns.histplot(df['LoanAmount'] , kde = True)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Count'>

# %%
df[continous].skew()
# Out:
# ApplicantIncome      6.539513
# CoapplicantIncome    7.491531
# LoanAmount           2.677552
# dtype: float64

# %%
sns.pairplot(df[continous])
plt.show()

# %%
sns.heatmap(df[continous].corr(),annot= True)
plt.show()

# %% [markdown]
# ## for discrete variable

# %%
df[discrete_categorical].describe()
# Out:
#        Gender Married Education Self_Employed Credit_History Property_Area  \
# count     601     611       614           582            564           614
# unique      2       2         2             2              2             3
# top      Male     Yes  Graduate            No           good     Semiurban
# freq      489     398       480           500            475           233
#
#        Loan_Status
# count          614
# unique           2
# top              Y
# freq           422

# %%
plt.rcParams['figure.figsize'] = (18,8)

plt.subplot(2,3,1)
sns.countplot(x = 'Gender' , data = df)

plt.subplot(2,3,2)
sns.countplot(x = 'Married' , data = df)

plt.subplot(2,3,3)
sns.countplot(x = 'Self_Employed' , data = df)

plt.suptitle('Univariate Analysis of the Categorical Columns')
plt.show()

# %% [markdown]
# # Data Preparation

# %%
df['Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']

df.drop(columns = ['ApplicantIncome' , 'CoapplicantIncome'] , inplace  = True)

# %% [markdown]
# ## Modifying the wrong Data

# %%
df['Dependents'] = df['Dependents'].replace({'3+':3})

# %% [markdown]
# ## Missing Value Treatment

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender              12
# Married              2
# Dependents           0
# Education            0
# Self_Employed       25
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# Income               0
# dtype: int64

# %%
df.isnull().sum()/len(df) *100
# Out:
# Loan_ID             0.0
# Gender              0.0
# Married             0.0
# Dependents          0.0
# Education           0.0
# Self_Employed       0.0
# LoanAmount          0.0
# Loan_Amount_Term    0.0
# Credit_History      0.0
# Property_Area       0.0
# Loan_Status         0.0
# Income              0.0
# dtype: float64

# %%
df = df.dropna(subset = ['Income' , 'LoanAmount' , 'Loan_Amount_Term' , 'Credit_History'])

# %%
df['Dependents'] = df['Dependents'].fillna(0)
# Out:
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\849717845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dependents'] = df['Dependents'].fillna(0)

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
# Out:
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\756931309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\756931309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\756931309.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %% [markdown]
# ## outliers Treatment
# ## not going to remove outliers as they are important for your model in this case only.

# %% [markdown]
# # Encoding

# %%
df['Gender'] = df['Gender'].map({'Male':1, 'Female' : 0}).astype('int')
df['Married'] = df['Married'].map({'Yes':1, 'No' : 0}).astype('int')
df['Education'] = df['Education'].map({'Graduate':1, 'Not Graduate' : 0}).astype('int')
df['Self_Employed'] = df['Self_Employed'].map({'Yes':1, 'No' : 0}).astype('int')
df['Property_Area'] = df['Property_Area'].map({'Rural':0, 'Semiurban' : 1 ,'Urban':2}).astype('int')
df['Credit_History'] = df['Credit_History'].map({'good':1, 'bad' : 0}).astype('int')
df['Loan_Status'] = df['Loan_Status'].map({'Y':1 , 'N' : 0}).astype('int')
# Out:
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\4058172216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].map({'Male':1, 'Female' : 0}).astype('int')
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\4058172216.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Married'] = df['Married'].map({'Yes':1, 'No' : 0}).astype('int')
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\4058172216.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Education'] = df['Education'].map({'Graduate':1, 'Not Graduate' : 0}).astype('int')
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\4058172216.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Self_Employed'] = df['Self_Employed'].map({'Yes':1, 'No' : 0}).astype('int')
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\4058172216.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Property_Area'] = df['Property_Area'].map({'Rural':0, 'Semiurban' : 1 ,'Urban':2}).astype('int')
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\4058172216.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Credit_History'] = df['Credit_History'].map({'good':1, 'bad' : 0}).astype('int')
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\4058172216.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Loan_Status'] = df['Loan_Status'].map({'Y':1 , 'N' : 0}).astype('int')

# %% [markdown]
# ## Datatype Conversion

# %%
df['Dependents'] = df['Dependents'].astype('int')
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].astype('int')
# Out:
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\3986743272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dependents'] = df['Dependents'].astype('int')
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\3986743272.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Loan_Amount_Term'] = df['Loan_Amount_Term'].astype('int')

# %% [markdown]
# ## Transformation

# %%
df[['Income', 'LoanAmount']].skew()
# Out:
# Income        5.777628
# LoanAmount    2.607945
# dtype: float64

# %%
#Applying Boxcox transformation to remove skewness

from scipy.stats import boxcox
df['Income'],a = boxcox(df['Income'])
df['LoanAmount'],c = boxcox(df['LoanAmount'])
# Out:
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\1036341173.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Income'],a = boxcox(df['Income'])
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\1036341173.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LoanAmount'],c = boxcox(df['LoanAmount'])

# %%
df[['LoanAmount' , 'Income']].skew()
# Out:
# LoanAmount    0.038289
# Income       -0.027769
# dtype: float64

# %%
df['Loan_Amount_Term'] =  df['Loan_Amount_Term'] /12
# Out:
# C:\Users\Talib\AppData\Local\Temp\ipykernel_5956\173387474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Loan_Amount_Term'] =  df['Loan_Amount_Term'] /12

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 1  LP001003       1        1           1          1              0
# 2  LP001005       1        1           0          1              1
# 3  LP001006       1        1           0          0              0
# 4  LP001008       1        0           0          1              0
# 5  LP001011       1        1           2          1              1
#
#    LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status  \
# 1    6.243267              30.0               1              0            0
# 2    5.202610              30.0               1              2            1
# 3    6.138816              30.0               1              2            1
# 4    6.401083              30.0               1              2            1
# 5    7.481930              30.0               1              2            1
#
#      Income
# 1  1.864967
# 2  1.856556
# 3  1.862802
# 4  1.864819
# 5  1.868932

# %%
df.to_csv('prepared_data.csv')
